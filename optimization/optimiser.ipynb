# %%
import numpy as np
import pandas as pd
import time
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# =====================================================
# 1. CONFIGURATION (CHANGE ONLY THIS PART)
# =====================================================

DATA_PATH = r"C:\Users\Sam\Desktop\ML\task\Data.xlsx"
sheet_name = "Data_after_KFold_DTC"
CONFIG = {
    "optimizer": "BOA",
    "population": 25,
    "iterations": 200,
    "cv": 5,
    "random_state": 42
}

# =====================================================
# 2. LOAD DATA
# =====================================================

df = pd.read_excel(DATA_PATH, sheet_name=sheet_name)
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

X = StandardScaler().fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=CONFIG["random_state"], stratify=y
)

MODEL = {
    "name": "DTC",
    "builder": DecisionTreeClassifier,
    "bounds": {
        "max_features": (1, X_train.shape[1], int),
        "criterion": (0, 1, int),              # 0=gini, 1=entropy
        "min_impurity_decrease": (0.0, 0.02, float),
        "ccp_alpha": (0.0, 0.05, float)
    }
}

# =====================================================
# 3. HELPER FUNCTIONS
# =====================================================

def bounds_to_arrays(bounds):
    lb, ub, cast = [], [], []
    for v in bounds.values():
        lb.append(v[0])
        ub.append(v[1])
        cast.append(v[2])
    return np.array(lb), np.array(ub), cast

def decode_params(vec, bounds, cast):
    decoded = {}
    for i, k in enumerate(bounds.keys()):
        val = cast[i](vec[i])
        if k == "criterion":
            decoded[k] = ["gini", "entropy"][val]
        else:
            decoded[k] = val
    return decoded

def make_objective(model_builder, bounds, cast):
    def objective(vec):
        params = decode_params(vec, bounds, cast)
        model = model_builder(**params, random_state=CONFIG["random_state"])
        score = cross_val_score(model, X_train, y_train, cv=CONFIG["cv"], scoring="accuracy").mean()
        return -score  # BOA minimizes
    return objective

# =====================================================
# 4. BUILDER OPTIMIZATION ALGORITHM (BOA)
# =====================================================

def BOA(objective, lb, ub, N, T, cast):
    start = time.time()
    D = len(lb)

    # --- Initialize population ---
    pop = lb + np.random.rand(N, D) * (ub - lb)
    fit = np.array([objective(pop[i]) for i in range(N)])

    best_idx = np.argmin(fit)
    best = pop[best_idx].copy()
    best_fit = fit[best_idx]

    convergence = []
    log = []

    for t in range(T):
        alpha = 1 - t / T
        mean_pop = np.mean(pop, axis=0)

        for i in range(N):
            candidate = pop[i] + alpha * np.random.randn(D) * (mean_pop - pop[i])
            candidate = np.clip(candidate, lb, ub)
            f = objective(candidate)

            # Update if improvement
            if f < fit[i]:
                pop[i] = candidate
                fit[i] = f
                if f < best_fit:
                    best, best_fit = candidate.copy(), f

        # --- Record convergence per iteration ---
        convergence.append(-best_fit)

        # --- Log only the best solution at this iteration ---
        best_decoded = decode_params(best, MODEL["bounds"], cast)
        log.append([t + 1] + [best_decoded[k] for k in MODEL["bounds"].keys()] + [-best_fit])

        # --- Print per iteration ---
        print(
            f"Iter {t+1:03d}, Best = "
            + ", ".join(f"{k}={v}" for k, v in best_decoded.items())
            + f", Acc = {-best_fit:.4f}"
        )

    runtime = time.time() - start
    return decode_params(best, MODEL["bounds"], cast), -best_fit, convergence, runtime, log

# =====================================================
# 5. RUN OPTIMIZATION
# =====================================================

lb, ub, cast = bounds_to_arrays(MODEL["bounds"])
objective = make_objective(MODEL["builder"], MODEL["bounds"], cast)

best, best_acc, convergence, runtime, log = BOA(
    objective, lb, ub, CONFIG["population"], CONFIG["iterations"], cast
)

# =====================================================
# 6. FINAL MODEL & REPORT
# =====================================================

best_params = best
final_model = MODEL["builder"](**best_params, random_state=CONFIG["random_state"])
final_model.fit(X_train, y_train)

test_acc = accuracy_score(y_test, final_model.predict(X_test))

# =====================================================
# 7. TABLES (EXCEL / PAPER READY)
# =====================================================

# Full iterations log
iter_cols = ["iteration"] + list(MODEL["bounds"].keys()) + ["best_cv_accuracy"]
iterations_df = pd.DataFrame(log, columns=iter_cols)


# Convergence per iteration
convergence_df = pd.DataFrame({"best_accuracy": convergence})

# Summary
summary_df = pd.DataFrame([{
    "Model": MODEL["name"],
    "Optimizer": CONFIG["optimizer"],
    # "Best_CV_Accuracy": best_acc,
    # "Test_Accuracy": test_acc,
    "Runtime_sec": runtime
}])

# Best hyperparameters table
best_params_df = pd.DataFrame({
    "parameters": list(best_params.keys()),
    "values": list(best_params.values())
})

# =========================
# PRINT RESULTS
# =========================
print("\n✅ Best Hyperparameters Table:")
print(best_params_df)

print("\n✅ Summary Table:")
print(summary_df)

print("\n✅ Iterations Log Preview:")
print(iterations_df.head(10))  # show first 10 rows

print("\n✅ Convergence Preview:")
print(convergence_df.head(10))
# Out:
# Iter 001, Best = max_features=3, criterion=gini, min_impurity_decrease=0.011676433231399273, ccp_alpha=0.006854978388088328, Acc = 0.7949
# Iter 002, Best = max_features=3, criterion=gini, min_impurity_decrease=0.011676433231399273, ccp_alpha=0.006854978388088328, Acc = 0.7949
# Iter 003, Best = max_features=3, criterion=gini, min_impurity_decrease=0.011676433231399273, ccp_alpha=0.006854978388088328, Acc = 0.7949
# Iter 004, Best = max_features=3, criterion=gini, min_impurity_decrease=0.011676433231399273, ccp_alpha=0.006854978388088328, Acc = 0.7949
# Iter 005, Best = max_features=3, criterion=gini, min_impurity_decrease=0.011676433231399273, ccp_alpha=0.006854978388088328, Acc = 0.7949
# Iter 006, Best = max_features=3, criterion=entropy, min_impurity_decrease=0.008757571863438302, ccp_alpha=0.030299498276784496, Acc = 0.7983
# Iter 007, Best = max_features=3, criterion=entropy, min_impurity_decrease=0.008757571863438302, ccp_alpha=0.030299498276784496, Acc = 0.7983
# Iter 008, Best = max_features=4, criterion=gini, min_impurity_decrease=0.0, ccp_alpha=0.0, Acc = 0.8159
# Iter 009, Best = max_features=5, criterion=gini, min_impurity_decrease=0.0012479617347454387, ccp_alpha=0.002069686721692797, Acc = 0.8229
# Iter 010, Best = max_features=6, criterion=gini, min_impurity_decrease=0.0, ccp_alpha=0.0, Acc = 0.8252
# Iter 011, Best = max_features=6, criterion=gini, min_impurity_decrease=0.0, ccp_alpha=0.0, Acc = 0.8252
# Iter 012, Best = max_features=6, criterion=gini, min_impurity_decrease=0.0, ccp_alpha=0.0, Acc = 0.8252
# Iter 013, Best = max_features=6, criterion=gini, min_impurity_decrease=0.0, ccp_alpha=0.0, Acc = 0.8252
# Iter 014, Best = max_features=6, criterion=gini, min_impurity_decrease=0.0, ccp_alpha=0.0, Acc = 0.8252
# Iter 015, Best = max_features=6, criterion=gini, min_impurity_decrease=0.0, ccp_alpha=0.0, Acc = 0.8252
# Iter 016, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0, ccp_alpha=0.0, Acc = 0.8333
# Iter 017, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0, ccp_alpha=0.0, Acc = 0.8333
# Iter 018, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0, ccp_alpha=0.0, Acc = 0.8333
# Iter 019, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0, ccp_alpha=0.0, Acc = 0.8333
# Iter 020, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0, ccp_alpha=0.0, Acc = 0.8333
# Iter 021, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0, ccp_alpha=0.0, Acc = 0.8333
# Iter 022, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0, ccp_alpha=0.0, Acc = 0.8333
# Iter 023, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0, ccp_alpha=0.0, Acc = 0.8333
# Iter 024, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0, ccp_alpha=0.0, Acc = 0.8333
# Iter 025, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0, ccp_alpha=0.0, Acc = 0.8333
# Iter 026, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0, ccp_alpha=0.0, Acc = 0.8333
# Iter 027, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0, ccp_alpha=0.0, Acc = 0.8333
# Iter 028, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0008518602443178938, ccp_alpha=0.0, Acc = 0.8345
# Iter 029, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0008518602443178938, ccp_alpha=0.0, Acc = 0.8345
# Iter 030, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0008518602443178938, ccp_alpha=0.0, Acc = 0.8345
# Iter 031, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0008518602443178938, ccp_alpha=0.0, Acc = 0.8345
# Iter 032, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0008518602443178938, ccp_alpha=0.0, Acc = 0.8345
# Iter 033, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0008518602443178938, ccp_alpha=0.0, Acc = 0.8345
# Iter 034, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0008518602443178938, ccp_alpha=0.0, Acc = 0.8345
# Iter 035, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0008518602443178938, ccp_alpha=0.0, Acc = 0.8345
# Iter 036, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0008518602443178938, ccp_alpha=0.0, Acc = 0.8345
# Iter 037, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0008518602443178938, ccp_alpha=0.0, Acc = 0.8345
# Iter 038, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 039, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 040, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 041, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 042, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 043, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 044, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 045, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 046, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 047, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 048, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 049, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 050, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 051, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 052, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 053, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 054, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 055, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 056, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 057, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 058, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 059, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 060, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 061, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 062, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 063, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 064, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 065, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 066, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 067, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 068, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 069, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 070, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 071, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 072, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 073, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 074, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 075, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 076, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 077, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 078, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 079, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 080, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 081, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 082, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 083, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 084, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 085, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 086, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 087, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 088, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 089, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 090, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 091, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 092, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 093, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 094, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 095, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 096, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 097, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 098, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 099, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 100, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 101, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 102, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 103, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 104, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 105, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 106, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 107, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 108, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0007386915815996318, ccp_alpha=0.0, Acc = 0.8368
# Iter 109, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 110, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 111, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 112, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 113, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 114, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 115, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 116, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 117, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 118, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 119, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 120, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 121, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 122, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 123, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 124, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 125, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 126, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 127, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 128, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 129, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 130, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 131, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 132, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 133, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 134, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 135, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 136, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 137, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 138, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 139, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 140, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 141, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 142, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 143, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 144, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 145, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 146, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 147, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 148, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 149, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 150, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 151, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 152, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 153, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 154, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 155, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 156, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 157, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 158, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 159, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 160, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 161, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 162, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 163, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 164, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 165, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 166, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 167, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 168, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 169, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 170, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 171, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 172, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 173, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 174, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 175, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 176, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 177, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 178, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 179, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 180, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 181, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 182, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 183, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 184, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 185, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 186, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 187, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 188, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 189, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 190, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 191, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 192, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 193, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 194, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 195, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 196, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 197, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 198, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 199, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
# Iter 200, Best = max_features=3, criterion=gini, min_impurity_decrease=0.0010029212148376905, ccp_alpha=0.0, Acc = 0.8368
#
# ✅ Best Hyperparameters Table:
#               parameters    values
# 0           max_features         3
# 1              criterion      gini
# 2  min_impurity_decrease  0.001003
# 3              ccp_alpha       0.0
#
# ✅ Summary Table:
#   Model Optimizer  Best_CV_Accuracy  Test_Accuracy  Runtime_sec
# 0   DTC       BOA          0.836815       0.818605    90.528793
#
# ✅ Iterations Log Preview:
#    iteration  max_features criterion  min_impurity_decrease  ccp_alpha  \
# 0          1             3      gini               0.011676   0.006855
# 1          2             3      gini               0.011676   0.006855
# 2          3             3      gini               0.011676   0.006855
# 3          4             3      gini               0.011676   0.006855
# 4          5             3      gini               0.011676   0.006855
# 5          6             3   entropy               0.008758   0.030299
# 6          7             3   entropy               0.008758   0.030299
# 7          8             4      gini               0.000000   0.000000
# 8          9             5      gini               0.001248   0.002070
# 9         10             6      gini               0.000000   0.000000
#
#    best_cv_accuracy
# 0          0.794873
# 1          0.794873
# 2          0.794873
# 3          0.794873
# 4          0.794873
# 5          0.798348
# 6          0.798348
# 7          0.815857
# 8          0.822855
# 9          0.825173
#
# ✅ Convergence Preview:
#    best_accuracy
# 0       0.794873
# 1       0.794873
# 2       0.794873
# 3       0.794873
# 4       0.794873
# 5       0.798348
# 6       0.798348
# 7       0.815857
# 8       0.822855
# 9       0.825173

# %%
iterations_df.to_clipboard(index=False)

# %%
convergence_df.to_clipboard(index=False)

# %%
summary_df.to_clipboard(index=False)

# %%
best_params_df.to_clipboard(index=False)
